# %% [markdown]
# <a href="https://colab.research.google.com/github/xanderluisvillamil/CS1-Phython-Grade7Gold-Villamil/blob/main/MaxNum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from ast import And
num1 = int(input("Enter a number"))
num2 = int(input("Enter another number"))
num3 = int(input("Enter the final number"))

if num1 > num2 and num3:
  print("The Largest number is", num1)
elif num2 > num1 and num3:
  print("The Largest number is", num2)
else:
  print("The Largest number is", num3)
