# %% [markdown]
# <a href="https://colab.research.google.com/github/xanderluisvillamil/CS1-Phython-Grade7Gold-Villamil/blob/main/fa5program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def total_groceries(price, amount):
  total = price * amount
  return total

Item = input("What is the name of the item? ")
Price = int(input("What is the price of the item? "))
Amount = int(input("How many items are there? "))

total = total_groceries(Price, Amount)
print("Your total expense is", total_groceries(Price, Amount))
